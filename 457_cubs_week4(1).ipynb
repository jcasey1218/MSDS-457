# %%
import pandas as pd # panda's nickname is pd
import numpy as np # numpy as np
from pandas import DataFrame, Series # for convenience
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.linear_model
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
from scipy import stats

# %% [markdown]
# # Part 1: Does Winning correlate with Payroll?  How much do the Cubs spend?

# %%
#Read Data
mlb_payroll=pd.read_csv('C:/Users/jcase/Downloads/mlb_payroll_1.csv')

# %%
mlb_payroll.head()
# Out:
#    place                  Team  Win %  Total Payroll  year  Championship  \
# 0      1        Boston Red Sox  0.519      229196106  2019             0
# 1      2      New York Yankees  0.636      223019037  2019             0
# 2      3          Chicago Cubs  0.519      221590085  2019             0
# 3      4   Los Angeles Dodgers  0.654      207000814  2019             0
# 4      5  San Francisco Giants  0.475      178582126  2019             0
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# ...

# %%
#Lets see the correlation between win percentage and total payroll for each year
#must make a data frame for each year and make a scatter plot for each year

#2019
Y19=mlb_payroll["year"]==2019
mlb_payroll_2019=mlb_payroll[Y19]
print(mlb_payroll_2019.head())
print(mlb_payroll_2019.tail())

#2018
Y18=mlb_payroll["year"]==2018
mlb_payroll_2018=mlb_payroll[Y18]
print(mlb_payroll_2018.head())
print(mlb_payroll_2018.tail())

#2017
Y17=mlb_payroll["year"]==2017
mlb_payroll_2017=mlb_payroll[Y17]
print(mlb_payroll_2017.head())
print(mlb_payroll_2017.tail())

#2016
Y16=mlb_payroll["year"]==2016
mlb_payroll_2016=mlb_payroll[Y16]
print(mlb_payroll_2016.head())
print(mlb_payroll_2016.tail())

#2015
Y15=mlb_payroll["year"]==2015
mlb_payroll_2015=mlb_payroll[Y15]
print(mlb_payroll_2015.head())
print(mlb_payroll_2015.tail())

#2014
Y14=mlb_payroll["year"]==2014
mlb_payroll_2014=mlb_payroll[Y14]
print(mlb_payroll_2014.head())
print(mlb_payroll_2014.tail())

#2013
Y13=mlb_payroll["year"]==2013
mlb_payroll_2013=mlb_payroll[Y13]
print(mlb_payroll_2013.head())
print(mlb_payroll_2013.tail())

#2012
Y12=mlb_payroll["year"]==2012
mlb_payroll_2012=mlb_payroll[Y12]
print(mlb_payroll_2012.head())
print(mlb_payroll_2012.tail())

#2011
Y11=mlb_payroll["year"]==2011
mlb_payroll_2011=mlb_payroll[Y11]
print(mlb_payroll_2011.head())
print(mlb_payroll_2011.tail())

#2010
Y10=mlb_payroll["year"]==2010
mlb_payroll_2010=mlb_payroll[Y10]
print(mlb_payroll_2010.head())
print(mlb_payroll_2010.tail())
# Out:
#    place                  Team  Win %  Total Payroll  year  Championship  \
# 0      1        Boston Red Sox  0.519      229196106  2019             0
# 1      2      New York Yankees  0.636      223019037  2019             0
# 2      3          Chicago Cubs  0.519      221590085  2019             0
# 3      4   Los Angeles Dodgers  0.654      207000814  2019             0
# 4      5  San Francisco Giants  0.475      178582126  2019             0
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# ...

# %%
#Scatter plots to see if there is correlation between Win % and Payroll
#all
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll)
plt.title("2010-19")
plt.show()


#2019
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2019)
plt.title("2019")
plt.show()

#2018
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2018)
plt.title("2018")
plt.show()

#2017
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2017)
plt.title("2017")
plt.show()

#2016
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2016)
plt.title("2016")
plt.show()

#2015
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2015)
plt.title("2015")
plt.show()

#2014
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2014)
plt.title("2014")
plt.show()

#2013
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2013)
plt.title("2013")
plt.show()

#2012
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2012)
plt.title("2012")
plt.show()

#2011
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2011)
plt.title("2011")
plt.show()

#2010
sns.regplot(x="Win %", y="Total Payroll", data=mlb_payroll_2010)
plt.title("2010")
plt.show()

# %%
#slope and r squared values of lin reg lines will show how correlated and general trend 
#2019
x = mlb_payroll['Win %']
y = mlb_payroll['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("2010-19 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2019
x = mlb_payroll_2019['Win %']
y = mlb_payroll_2019['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2019 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2018
x = mlb_payroll_2018['Win %']
y = mlb_payroll_2018['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2018 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2017
x = mlb_payroll_2017['Win %']
y = mlb_payroll_2017['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2017 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2016
x = mlb_payroll_2016['Win %']
y = mlb_payroll_2016['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2016 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2015
x = mlb_payroll_2015['Win %']
y = mlb_payroll_2015['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2015 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2014
x = mlb_payroll_2014['Win %']
y = mlb_payroll_2014['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2014 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2013
x = mlb_payroll_2013['Win %']
y = mlb_payroll_2013['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2013 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2012
x = mlb_payroll_2012['Win %']
y = mlb_payroll_2012['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2012 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2011
x = mlb_payroll_2011['Win %']
y = mlb_payroll_2011['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2011 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2010
x = mlb_payroll_2010['Win %']
y = mlb_payroll_2010['Total Payroll']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2010 Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)
# Out:
# 2010-19 Slope and R^2 Value
# Slope: 208220486.39974216
# R^2 Value: 0.10891364870965209
#
# 2019 Slope and R^2 Value
# Slope: 207922571.31652662
# R^2 Value: 0.19720583005311335
#
# 2018 Slope and R^2 Value
# Slope: 172205055.06961858
# R^2 Value: 0.1420032905835979
#
# 2017 Slope and R^2 Value
# Slope: 234492665.14327323
# R^2 Value: 0.1249103796709394
#
# 2016 Slope and R^2 Value
# Slope: 437097242.4942173
# R^2 Value: 0.36877789350171675
#
# 2015 Slope and R^2 Value
# Slope: 121021063.56212683
# R^2 Value: 0.03690499498620661
#
# 2014 Slope and R^2 Value
# Slope: 217854634.35805517
# R^2 Value: 0.08824232101748644
#
# 2013 Slope and R^2 Value
# Slope: 191691013.2109753
# R^2 Value: 0.09961398529157661
#
# 2012 Slope and R^2 Value
# Slope: 101098190.60793976
# R^2 Value: 0.039097951246465174
#
# 2011 Slope and R^2 Value
# Slope: 236879544.54416794
# R^2 Value: 0.16754746950788962
#
# 2010 Slope and R^2 Value
# Slope: 195651065.3986265
# R^2 Value: 0.1207069641535938

# %%
#stats by team
df=mlb_payroll.groupby(['Team'], sort=True).sum().reset_index()
df1= df[["Team","Win %","Total Payroll","Championship"] ]
df1["Win %"]=df1["Win %"]/10
df1.sort_values(by=["Win %"],ascending=False)
# Out:
# C:\Users\jcase\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                      Team   Win %  Total Payroll  Championship
# 18       New York Yankees  0.5686     2093928503             0
# 13    Los Angeles Dodgers  0.5672     1895570267             0
# 25    St. Louis Cardinals  0.5550     1289843149             1
# 29   Washington Nationals  0.5429     1310980911             1
# 3          Boston Red Sox  0.5383     1854504688             2
# 26         Tampa Bay Rays  0.5307      661013706             0
# 7       Cleveland Indians  0.5286      922687976             0
# 1          Atlanta Braves  0.5207     1009181957             0
# ...

# %%
df1.sort_values(by=["Total Payroll"],ascending=False)
# Out:
#                      Team   Win %  Total Payroll  Championship
# 18       New York Yankees  0.5686     2093928503             0
# 13    Los Angeles Dodgers  0.5672     1895570267             0
# 3          Boston Red Sox  0.5383     1854504688             2
# 12     Los Angeles Angels  0.5074     1510329215             0
# 23   San Francisco Giants  0.5068     1506386645             3
# 9          Detroit Tigers  0.4835     1478548191             0
# 4            Chicago Cubs  0.5045     1425813188             1
# 20  Philadelphia Phillies  0.4859     1424905307             0
# 29   Washington Nationals  0.5429     1310980911             1
# 27          Texas Rangers  0.5200     1289872747             0
# 25    St. Louis Cardinals  0.5550     1289843149             1
# 24       Seattle Mariners  0.4679     1213904995             0
# 17          New York Mets  0.4896     1194591553             0
# 28      Toronto Blue Jays  0.4902     1146551624             0
# ...

# %%
df1.sort_values(by=["Championship"],ascending=False)
# Out:
#                      Team   Win %  Total Payroll  Championship
# 23   San Francisco Giants  0.5068     1506386645             3
# 3          Boston Red Sox  0.5383     1854504688             2
# 29   Washington Nationals  0.5429     1310980911             1
# 11     Kansas City Royals  0.4678      975302301             1
# 4            Chicago Cubs  0.5045     1425813188             1
# 25    St. Louis Cardinals  0.5550     1289843149             1
# 10         Houston Astros  0.4871      929319230             1
# 19      Oakland Athletics  0.5085      739339255             0
# 20  Philadelphia Phillies  0.4859     1424905307             0
# 21     Pittsburgh Pirates  0.4894      735629886             0
# 22       San Diego Padres  0.4561      813883967             0
# 24       Seattle Mariners  0.4679     1213904995             0
# 17          New York Mets  0.4896     1194591553             0
# 26         Tampa Bay Rays  0.5307      661013706             0
# ...

# %%
#Win%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
teams = df1["Team"]
AveWinPer = df1["Win %"]
ax.bar(teams,AveWinPer)
ax.set_ylim([0.3,0.6])
plt.xticks(rotation=90)
plt.show()

#payroll
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
teams = df1["Team"]
pr = df1["Total Payroll"]
ax.bar(teams,pr)
plt.xticks(rotation=90)
plt.show()

# %%
df2= df[["Team","Win %","Total Payroll"] ]
df2
# Out:
#                      Team  Win %  Total Payroll
# 0    Arizona Diamondbacks  4.895      920789745
# 1          Atlanta Braves  5.207     1009181957
# 2       Baltimore Orioles  4.660     1093377841
# 3          Boston Red Sox  5.383     1854504688
# 4            Chicago Cubs  5.045     1425813188
# 5       Chicago White Sox  4.590     1024511458
# 6         Cincinnati Reds  4.786      989530870
# 7       Cleveland Indians  5.286      922687976
# 8        Colorado Rockies  4.638     1073685040
# 9          Detroit Tigers  4.835     1478548191
# 10         Houston Astros  4.871      929319230
# 11     Kansas City Royals  4.678      975302301
# 12     Los Angeles Angels  5.074     1510329215
# 13    Los Angeles Dodgers  5.672     1895570267
# 14          Miami Marlins  4.369      751132530
# 15      Milwaukee Brewers  5.083      934571296
# 16        Minnesota Twins  4.720     1040387761
# 17          New York Mets  4.896     1194591553
# 18       New York Yankees  5.686     2093928503
# ...

# %%
#Let look at allocation of money - money spent on pitchers v win %
mlb_salary=pd.read_csv('C:/Users/jcase/Downloads/mlb_salary_1.csv')

# %%
mlb_salary.head()
# Out:
#    Year  RANK               NAME                  TEAM POS    SALARY  \
# 0  2019     1       Max Scherzer  Washington Nationals  SP  42142857
# 1  2019     2  Stephen Strasburg  Washington Nationals  SP  36428571
# 2  2019     3         Mike Trout     Los Angeles Angel  CF  34083333
# 3  2019     4       Zack Greinke  Arizona Diamondbacks  SP  32421884
# 4  2019     5        David Price        Boston Red Sox  SP  31000000
#
#          YEARS  TOTAL VALUE AVG ANNUAL
# 0  7 (2015-21)    210000000   30000000
# 1  7 (2017-23)    175000000   25000000
# 2  6 (2015-20)    144500000   24083333
# 3  6 (2016-21)    206500000   34416667
# 4  7 (2016-22)    217000000   31000000

# %%
#2019
SY19=mlb_salary["Year"]==2019
mlb_salary_2019=mlb_salary[SY19]
print(mlb_salary_2019.head())
print(mlb_salary_2019.tail())

#2018
SY18=mlb_salary["Year"]==2018
mlb_salary_2018=mlb_salary[SY18]
print(mlb_salary_2018.head())
print(mlb_salary_2018.tail())

#2017
SY17=mlb_salary["Year"]==2018
mlb_salary_2017=mlb_salary[SY17]
print(mlb_salary_2017.head())
print(mlb_salary_2017.tail())

#2016
SY16=mlb_salary["Year"]==2016
mlb_salary_2016=mlb_salary[SY16]
print(mlb_salary_2016.head())
print(mlb_salary_2016.tail())

#2015
SY15=mlb_salary["Year"]==2015
mlb_salary_2015=mlb_salary[SY15]
print(mlb_salary_2015.head())
print(mlb_salary_2015.tail())

#2014
SY14=mlb_salary["Year"]==2014
mlb_salary_2014=mlb_salary[SY14]
print(mlb_salary_2014.head())
print(mlb_salary_2014.tail())

#2013
SY13=mlb_salary["Year"]==2013
mlb_salary_2013=mlb_salary[SY13]
print(mlb_salary_2013.head())
print(mlb_salary_2013.tail())

#2012
SY12=mlb_salary["Year"]==2012
mlb_salary_2012=mlb_salary[SY12]
print(mlb_salary_2012.head())
print(mlb_salary_2012.tail())

#2011
SY11=mlb_salary["Year"]==2011
mlb_salary_2011=mlb_salary[SY11]
print(mlb_salary_2011.head())
print(mlb_salary_2011.tail())

#2010
SY10=mlb_salary["Year"]==2010
mlb_salary_2010=mlb_salary[SY10]
print(mlb_salary_2010.head())
print(mlb_salary_2010.tail())
# Out:
#    Year  RANK               NAME                  TEAM POS    SALARY  \
# 0  2019     1       Max Scherzer  Washington Nationals  SP  42142857
# 1  2019     2  Stephen Strasburg  Washington Nationals  SP  36428571
# 2  2019     3         Mike Trout     Los Angeles Angel  CF  34083333
# 3  2019     4       Zack Greinke  Arizona Diamondbacks  SP  32421884
# 4  2019     5        David Price        Boston Red Sox  SP  31000000
#
#          YEARS  TOTAL VALUE AVG ANNUAL
# 0  7 (2015-21)    210000000   30000000
# 1  7 (2017-23)    175000000   25000000
# 2  6 (2015-20)    144500000   24083333
# 3  6 (2016-21)    206500000   34416667
# 4  7 (2016-22)    217000000   31000000
#      Year  RANK             NAME                  TEAM POS  SALARY     YEARS  \
# 872  2019   837  Frank Schwindel    Kansas City Royals  1B  555000  1 (2019)
# 873  2019   837     Nick Vincent  San Francisco Giants  RP  555000  1 (2019)
# 874  2019   837     Rowdy Tellez     Toronto Blue Jays  1B  555000  1 (2019)
# ...

# %%
#Let's see if teams that spend more money on pitchers have a higher correlation with win percentage
filterlist=["SP","P","RP"]


#2019
Pitcher19=mlb_salary_2019[mlb_salary_2019.POS.isin(filterlist)]
pt19 = Pitcher19.groupby(["TEAM"]).sum()

sal_19=pd.DataFrame(pt19["SALARY"])
pay19=mlb_payroll_2019[["Team","Win %"]]

pay_19=pay19.sort_values(by=["Team"],ascending=True).set_index(sal_19.index)
reg19=pd.merge(left=pay_19,right=sal_19,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg19)
plt.title("2019")
plt.show()

#2018
Pitcher18=mlb_salary_2018[mlb_salary_2018.POS.isin(filterlist)]
pt18 = Pitcher18.groupby(["TEAM"]).sum()

sal_18=pd.DataFrame(pt18["SALARY"])
pay18=mlb_payroll_2018[["Team","Win %"]]

pay_18=pay18.sort_values(by=["Team"],ascending=True).set_index(sal_18.index)
reg18=pd.merge(left=pay_18,right=sal_18,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg18)
plt.title("2018")
plt.show()

#2017
Pitcher17=mlb_salary_2017[mlb_salary_2017.POS.isin(filterlist)]
pt17 = Pitcher17.groupby(["TEAM"]).sum()

sal_17=pd.DataFrame(pt17["SALARY"])
pay17=mlb_payroll_2017[["Team","Win %"]]

pay_17=pay17.sort_values(by=["Team"],ascending=True).set_index(sal_17.index)
reg17=pd.merge(left=pay_17,right=sal_17,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg17)
plt.title("2017")
plt.show()

#2016
Pitcher16=mlb_salary_2016[mlb_salary_2016.POS.isin(filterlist)]
pt16 = Pitcher16.groupby(["TEAM"]).sum()

sal_16=pd.DataFrame(pt16["SALARY"])
pay16=mlb_payroll_2016[["Team","Win %"]]

pay_16=pay16.sort_values(by=["Team"],ascending=True).set_index(sal_16.index)
reg16=pd.merge(left=pay_16,right=sal_16,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg16)
plt.title("2016")
plt.show()

#2015
Pitcher15=mlb_salary_2015[mlb_salary_2015.POS.isin(filterlist)]
pt15 = Pitcher15.groupby(["TEAM"]).sum()

sal_15=pd.DataFrame(pt15["SALARY"])
pay15=mlb_payroll_2015[["Team","Win %"]]

pay_15=pay15.sort_values(by=["Team"],ascending=True).set_index(sal_15.index)
reg15=pd.merge(left=pay_15,right=sal_15,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg15)
plt.title("2015")
plt.show()

#2014
Pitcher14=mlb_salary_2014[mlb_salary_2014.POS.isin(filterlist)]
pt14 = Pitcher14.groupby(["TEAM"]).sum()

sal_14=pd.DataFrame(pt14["SALARY"])
pay14=mlb_payroll_2014[["Team","Win %"]]

pay_14=pay14.sort_values(by=["Team"],ascending=True).set_index(sal_14.index)
reg14=pd.merge(left=pay_14,right=sal_14,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg14)
plt.title("2014")
plt.show()

#2013
Pitcher13=mlb_salary_2013[mlb_salary_2013.POS.isin(filterlist)]
pt13 = Pitcher13.groupby(["TEAM"]).sum()

sal_13=pd.DataFrame(pt13["SALARY"])
pay13=mlb_payroll_2013[["Team","Win %"]]

pay_13=pay13.sort_values(by=["Team"],ascending=True).set_index(sal_13.index)
reg13=pd.merge(left=pay_13,right=sal_13,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg13)
plt.title("2013")
plt.show()

#2012
Pitcher12=mlb_salary_2012[mlb_salary_2012.POS.isin(filterlist)]
pt12 = Pitcher12.groupby(["TEAM"]).sum()

sal_12=pd.DataFrame(pt12["SALARY"])
pay12=mlb_payroll_2012[["Team","Win %"]]

pay_12=pay12.sort_values(by=["Team"],ascending=True).set_index(sal_12.index)
reg12=pd.merge(left=pay_12,right=sal_12,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg16)
plt.title("2012")
plt.show()

#2011
Pitcher11=mlb_salary_2011[mlb_salary_2011.POS.isin(filterlist)]
pt11 = Pitcher11.groupby(["TEAM"]).sum()

sal_11=pd.DataFrame(pt11["SALARY"])
pay11=mlb_payroll_2011[["Team","Win %"]]

pay_11=pay11.sort_values(by=["Team"],ascending=True).set_index(sal_11.index)
reg11=pd.merge(left=pay_11,right=sal_11,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg11)
plt.title("2011")
plt.show()

#2010
Pitcher10=mlb_salary_2010[mlb_salary_2010.POS.isin(filterlist)]
pt10 = Pitcher10.groupby(["TEAM"]).sum()

sal_10=pd.DataFrame(pt10["SALARY"])
pay10=mlb_payroll_2010[["Team","Win %"]]

pay_10=pay10.sort_values(by=["Team"],ascending=True).set_index(sal_10.index)
reg10=pd.merge(left=pay_10,right=sal_10,how='left', left_on='TEAM', right_on='TEAM')

sns.regplot(x="Win %", y="SALARY", data=reg10)
plt.title("2010")
plt.show()

# %%
#Let's check the r squared and slope of these plots
#2019
x = reg19['Win %']
y = reg19['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2019 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2018
x = reg18['Win %']
y = reg18['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2018 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2017
x = reg17['Win %']
y = reg17['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2017 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2016
x = reg16['Win %']
y = reg16['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2016 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2015
x = reg15['Win %']
y = reg15['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2015 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2014
x = reg14['Win %']
y = reg14['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2014 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2013
x = reg13['Win %']
y = reg13['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2013 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2012
x = reg12['Win %']
y = reg12['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2012 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2011
x = reg11['Win %']
y = reg11['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2011 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)

#2010
x = reg10['Win %']
y = reg10['SALARY']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print()
print("2010 Pitcher Salary Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)
# Out:
# 2019 Pitcher Salary Slope and R^2 Value
# Slope: 127427083.77907163
# R^2 Value: 0.17033098850940084
#
# 2018 Pitcher Salary Slope and R^2 Value
# Slope: 75501363.02450368
# R^2 Value: 0.0735024401327018
#
# 2017 Pitcher Salary Slope and R^2 Value
# Slope: 179420936.57342723
# R^2 Value: 0.25788663731793254
#
# 2016 Pitcher Salary Slope and R^2 Value
# Slope: 191324585.68058148
# R^2 Value: 0.25759188057382365
#
# 2015 Pitcher Salary Slope and R^2 Value
# Slope: 46230695.78929899
# R^2 Value: 0.02069831656450365
#
# 2014 Pitcher Salary Slope and R^2 Value
# Slope: 73851825.11950766
# R^2 Value: 0.03098143921840555
#
# 2013 Pitcher Salary Slope and R^2 Value
# Slope: 61814876.60033783
# R^2 Value: 0.04562469171206624
#
# 2012 Pitcher Salary Slope and R^2 Value
# Slope: -1314190.7186978636
# R^2 Value: 2.6635303387862784e-05
#
# 2011 Pitcher Salary Slope and R^2 Value
# Slope: 123535252.82246031
# R^2 Value: 0.1764345814514741
#
# 2010 Pitcher Salary Slope and R^2 Value
# ...

# %% [markdown]
# # Part 2: Valuation can be found in Cubs Net Value Spreadsheet

# %% [markdown]
# # Part 3: WAR analysis

# %%
#WAR Analysis datasets
Cubs_Batting=pd.read_csv('C:/Users/jcase/Downloads/Cubs_Batting_War.csv')
Cubs_Pitching=pd.read_csv('C:/Users/jcase/Downloads/Cubs_Pitching_War.csv')
League_WAR=pd.read_csv('C:/Users/jcase/Downloads/League_War.csv')
League_Pitching_WAR=pd.read_csv('C:/Users/jcase/Downloads/League_Pitching_War.csv')
mlb_player_batting=pd.read_csv('C:/Users/jcase/Downloads/mlb_batting_war.csv')
mlb_player_pitching=pd.read_csv('C:/Users/jcase/Downloads/mlb_pitching_war.csv')

# %%
Cubs_Batting
# Out:
#                  Name  Batting  Base Running  Fielding  Positional  Offense  \
# 0         Kris Bryant     29.0           3.8      -3.7        -0.4     32.9
# 1         Javier Baez     10.0           1.2      10.2         5.5     11.2
# 2       Anthony Rizzo     33.5          -5.4       3.7       -10.5     28.1
# 3   Willson Contreras     14.7           0.2      -7.0         6.7     14.9
# 4      Kyle Schwarber     16.1          -2.3      -0.9        -6.2     13.8
# 5       Jason Heyward      0.6           2.1       0.4        -2.1      2.6
# 6          David Bote      2.8           2.4      -2.7         1.3      5.2
# 7            Ian Happ      5.6           1.4       3.3        -0.3      7.0
# 8     Victor Caratini      2.8          -1.5       1.8         2.6      1.3
# 9     Addison Russell     -6.2           0.6       1.9         1.4     -5.6
# 10        Ben Zobrist     -3.6          -1.9       2.7        -0.4     -5.5
# ...

# %%
Cubs_Pitching
# Out:
#                 Name  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins   RAR  WAR  \
# 0     Kyle Hendricks      4.0       0.3      -0.5      -0.1  40.2  4.1
# 1      Jose Quintana      1.3      -1.4      -0.8      -2.1  34.6  3.5
# 2         Jon Lester      1.4      -2.2       0.8      -1.4  27.8  2.8
# 3         Yu Darvish      3.6       0.9       0.0       1.0  26.3  2.6
# 4        Cole Hamels      3.0      -0.7       1.2       0.5  24.9  2.5
# 5   Brandon Kintzler      1.6       0.5       0.2       0.8   8.7  0.9
# 6     Tyler Chatwood      1.3       0.2       0.5       0.7   6.5  0.6
# 7         Brad Brach     -0.4      -0.7       0.0      -0.7   2.8  0.3
# 8       Steve Cishek      1.7       0.7       0.8       1.5   2.0  0.2
# 9        Pedro Strop     -0.1       0.2      -0.3      -0.1   0.4  0.0
# 10     Xavier Cedeno      0.1      -0.1       0.3       0.1  -0.4  0.0
# 11  Carl Edwards Jr.     -0.2       0.4      -0.6      -0.2  -0.7 -0.1
# ...

# %%
CB_Dif=pd.DataFrame(Cubs_Batting["Worth"]-Cubs_Batting["Salary"])
CB_Dif.set_index(Cubs_Batting.Name)
# Out:
#                           0
# Name
# Kris Bryant        25500000
# Javier Baez        29900000
# Anthony Rizzo      19714286
# Willson Contreras  21016000
# Kyle Schwarber     17210000
# Jason Heyward      -4500000
# David Bote         11338500
# Ian Happ           11096500
# Victor Caratini    10830500
# Addison Russell      800000
# Ben Zobrist       -10500000
# Mark Zagunis       -2156500
# Albert Almora Jr.  -6415500
# Daniel Descalso    -8600000

# %%
CP_Dif=pd.DataFrame(Cubs_Pitching["Worth"]-Cubs_Pitching["Salary"])
CP_Dif.set_index(Cubs_Pitching.Name)
# Out:
#                          0
# Name
# Kyle Hendricks    25495000
# Jose Quintana     17500000
# Jon Lester        -5400000
# Yu Darvish          700000
# Cole Hamels        -100000
# Brandon Kintzler   1900000
# Tyler Chatwood    -7400000
# Brad Brach         -800000
# Steve Cishek      -5900000
# Pedro Strop       -5950000
# Xavier Cedeno     -1200000
# Carl Edwards Jr.  -2000000
# Randy Rosario     -1064000
# Victor Caratini   -1069500
# Tony Barnette     -1550000
# Mike Montgomery   -6740000
# Craig Kimbrel    -18400000

# %%
dfb={"Name":Cubs_Batting['Name'],"Difference":Cubs_Batting["Worth"]-Cubs_Batting["Salary"]}

CB_Dif=pd.DataFrame(dfb)
CB_Dif
# Out:
#                  Name  Difference
# 0         Kris Bryant    25500000
# 1         Javier Baez    29900000
# 2       Anthony Rizzo    19714286
# 3   Willson Contreras    21016000
# 4      Kyle Schwarber    17210000
# 5       Jason Heyward    -4500000
# 6          David Bote    11338500
# 7            Ian Happ    11096500
# 8     Victor Caratini    10830500
# 9     Addison Russell      800000
# 10        Ben Zobrist   -10500000
# 11       Mark Zagunis    -2156500
# 12  Albert Almora Jr.    -6415500
# 13    Daniel Descalso    -8600000

# %%
#Looking at the difference between worth and salary for position players
chart= sns.barplot(x='Name',y='Difference',data=CB_Dif)
sns.set(rc={'figure.figsize':(5,5)})
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Kris Bryant'),
#  Text(0,0,'Javier Baez'),
#  Text(0,0,'Anthony Rizzo'),
#  Text(0,0,'Willson Contreras'),
#  Text(0,0,'Kyle Schwarber'),
#  Text(0,0,'Jason Heyward'),
#  Text(0,0,'David Bote'),
#  Text(0,0,'Ian Happ'),
#  Text(0,0,'Victor Caratini'),
#  Text(0,0,'Addison Russell'),
#  Text(0,0,'Ben Zobrist'),
#  Text(0,0,'Mark Zagunis'),
#  Text(0,0,'Albert Almora Jr.'),
#  Text(0,0,'Daniel Descalso')]

# %%
dfp={"Name":Cubs_Pitching['Name'],"Difference":Cubs_Pitching["Worth"]-Cubs_Pitching["Salary"]}

CP_Dif=pd.DataFrame(dfp)
CP_Dif
# Out:
#                 Name  Difference
# 0     Kyle Hendricks    25495000
# 1      Jose Quintana    17500000
# 2         Jon Lester    -5400000
# 3         Yu Darvish      700000
# 4        Cole Hamels     -100000
# 5   Brandon Kintzler     1900000
# 6     Tyler Chatwood    -7400000
# 7         Brad Brach     -800000
# 8       Steve Cishek    -5900000
# 9        Pedro Strop    -5950000
# 10     Xavier Cedeno    -1200000
# 11  Carl Edwards Jr.    -2000000
# 12     Randy Rosario    -1064000
# 13   Victor Caratini    -1069500
# 14     Tony Barnette    -1550000
# 15   Mike Montgomery    -6740000
# 16     Craig Kimbrel   -18400000

# %%
#Looking at the difference between worth and salary for pitchers
chart= sns.barplot(x='Name',y='Difference',data=CP_Dif)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Kyle Hendricks'),
#  Text(0,0,'Jose Quintana'),
#  Text(0,0,'Jon Lester'),
#  Text(0,0,'Yu Darvish'),
#  Text(0,0,'Cole Hamels'),
#  Text(0,0,'Brandon Kintzler'),
#  Text(0,0,'Tyler Chatwood'),
#  Text(0,0,'Brad Brach'),
#  Text(0,0,'Steve Cishek'),
#  Text(0,0,'Pedro Strop'),
#  Text(0,0,'Xavier Cedeno'),
#  Text(0,0,'Carl Edwards Jr.'),
#  Text(0,0,'Randy Rosario'),
#  Text(0,0,'Victor Caratini'),
#  Text(0,0,'Tony Barnette'),
#  Text(0,0,'Mike Montgomery'),
#  Text(0,0,'Craig Kimbrel')]

# %%
#Total Differences
print("Cubs Batting Difference:")
print(CB_Dif['Difference'].sum())

print("Cubs Pitching Difference:")
print(CP_Dif['Difference'].sum())
# Out:
# Cubs Batting Difference:
# 115233786
# Cubs Pitching Difference:
# -11978500

# %%
CB_WAR=pd.DataFrame([Cubs_Batting["Name"],Cubs_Batting["WAR"]]).transpose()
CP_WAR=pd.DataFrame([Cubs_Pitching["Name"],Cubs_Pitching["WAR"]]).transpose()

# %%
#Looking at the WAR for position players
chart= sns.barplot(x='Name',y='WAR',data=CB_WAR)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Kris Bryant'),
#  Text(0,0,'Javier Baez'),
#  Text(0,0,'Anthony Rizzo'),
#  Text(0,0,'Willson Contreras'),
#  Text(0,0,'Kyle Schwarber'),
#  Text(0,0,'Jason Heyward'),
#  Text(0,0,'David Bote'),
#  Text(0,0,'Ian Happ'),
#  Text(0,0,'Victor Caratini'),
#  Text(0,0,'Addison Russell'),
#  Text(0,0,'Ben Zobrist'),
#  Text(0,0,'Mark Zagunis'),
#  Text(0,0,'Albert Almora Jr.'),
#  Text(0,0,'Daniel Descalso')]

# %%
#Looking at the WAR for pitchers
chart= sns.barplot(x='Name',y='WAR',data=CP_WAR)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Kyle Hendricks'),
#  Text(0,0,'Jose Quintana'),
#  Text(0,0,'Jon Lester'),
#  Text(0,0,'Yu Darvish'),
#  Text(0,0,'Cole Hamels'),
#  Text(0,0,'Brandon Kintzler'),
#  Text(0,0,'Tyler Chatwood'),
#  Text(0,0,'Brad Brach'),
#  Text(0,0,'Steve Cishek'),
#  Text(0,0,'Pedro Strop'),
#  Text(0,0,'Xavier Cedeno'),
#  Text(0,0,'Carl Edwards Jr.'),
#  Text(0,0,'Randy Rosario'),
#  Text(0,0,'Victor Caratini'),
#  Text(0,0,'Tony Barnette'),
#  Text(0,0,'Mike Montgomery'),
#  Text(0,0,'Craig Kimbrel')]

# %%
#Difference between worth and salary for league
mlb_player_batting
dfb1={"Name":mlb_player_batting['Name'],"Difference":mlb_player_batting["Worth"]-mlb_player_batting["Salary"]}
mlb_pb=pd.DataFrame(dfb1)
mlb_pb
# Out:
#                   Name  Difference
# 0           Adam Eaton  -6400000.0
# 1         Adam Frazier   1616000.0
# 2           Adam Jones  -3100000.0
# 3        Albert Pujols -28400000.0
# 4         Alex Bregman   7859500.0
# 5          Alex Gordon -19700000.0
# 6         Amed Rosario   2124500.0
# 7    Andrew Benintendi   1282500.0
# 8       Anthony Rendon -11800000.0
# 9        Anthony Rizzo  -8285714.0
# 10    Asdrubal Cabrera  -1600000.0
# 11      Austin Meadows   3442600.0
# 12      Avisail Garcia  -1700000.0
# 13        Brandon Belt -16700000.0
# 14    Brandon Crawford -14800000.0
# 15       Brett Gardner  -3900000.0
# 16      Brian Anderson   2515000.0
# 17      Bryan Reynolds         NaN
# 18        Bryce Harper  -6938461.0
# 19      Carlos Santana -16100000.0
# 20     Cesar Hernandez  -6050000.0
# 21    Charlie Blackmon -19516666.0
# 22   Christian Vazquez    566667.0
# 23    Christian Walker   1640200.0
# 24    Christian Yelich  -2128571.0
# 25      Cody Bellinger   7195000.0
# ...

# %%
#Difference between worth and salary for MLB
chart= sns.barplot(x='Name',y='Difference',data=mlb_pb)
sns.set(rc={'figure.figsize':(80,20)})
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Adam Eaton'),
#  Text(0,0,'Adam Frazier'),
#  Text(0,0,'Adam Jones'),
#  Text(0,0,'Albert Pujols'),
#  Text(0,0,'Alex Bregman'),
#  Text(0,0,'Alex Gordon'),
#  Text(0,0,'Amed Rosario'),
#  Text(0,0,'Andrew Benintendi'),
#  Text(0,0,'Anthony Rendon'),
#  Text(0,0,'Anthony Rizzo'),
#  Text(0,0,'Asdrubal Cabrera'),
#  Text(0,0,'Austin Meadows'),
#  Text(0,0,'Avisail Garcia'),
#  Text(0,0,'Brandon Belt'),
#  Text(0,0,'Brandon Crawford'),
#  Text(0,0,'Brett Gardner'),
#  Text(0,0,'Brian Anderson'),
#  Text(0,0,'Bryan Reynolds'),
#  Text(0,0,'Bryce Harper'),
#  Text(0,0,'Carlos Santana'),
#  Text(0,0,'Cesar Hernandez'),
#  Text(0,0,'Charlie Blackmon'),
#  Text(0,0,'Christian Vazquez'),
#  Text(0,0,'Christian Walker'),
#  Text(0,0,'Christian Yelich'),
#  Text(0,0,'Cody Bellinger'),
#  Text(0,0,'Colin Moran'),
#  Text(0,0,'Corey Seager'),
#  Text(0,0,'Daniel Vogelbach'),
#  Text(0,0,'Dansby Swanson'),
#  Text(0,0,'David Fletcher'),
#  Text(0,0,'Dexter Fowler'),
# ...

# %%
#Difference between worth and salary for MLB (pitchers)
mlb_player_pitching
dfp1={"Name":mlb_player_pitching['Name'],"Difference":mlb_player_pitching["Worth"]-mlb_player_pitching["Salary"]}
mlb_pp=pd.DataFrame(dfp1)
mlb_pp
# Out:
#                   Name  Difference
# 0           Aaron Nola    21837500
# 1      Adam Wainwright    15200000
# 2       Anibal Sanchez     7550000
# 3   Anthony DeSclafani    17275000
# 4          Brad Keller    17121825
# 5       Brett Anderson    14300000
# 6       Charlie Morton    33500000
# 7      Clayton Kershaw    -3900000
# 8        Dakota Hudson     7640900
# 9    Eduardo Rodriguez    25300000
# 10      German Marquez    26635000
# 11         Gerrit Cole    45800000
# 12        Hyun-Jin Ryu    20400000
# 13           Ivan Nova     6633333
# 14       Jack Flaherty    37337900
# 15        Jacob deGrom    47000000
# 16         Jakob Junis    11521750
# 17     Jeff Samardzija    -8200000
# 18        Joe Musgrove    25917500
# 19       Joey Lucchesi    16534900
# 20          Jon Lester    -5400000
# 21        Jose Berrios    34580000
# 22       Jose Quintana    17500000
# 23       Julio Teheran     1733334
# 24    Justin Verlander    22900000
# 25      Kyle Hendricks    25495000
# ...

# %%
#plot of difference for pitchers
chart= sns.barplot(x='Name',y='Difference',data=mlb_pp)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Aaron Nola'),
#  Text(0,0,'Adam Wainwright'),
#  Text(0,0,'Anibal Sanchez'),
#  Text(0,0,'Anthony DeSclafani'),
#  Text(0,0,'Brad Keller'),
#  Text(0,0,'Brett Anderson'),
#  Text(0,0,'Charlie Morton'),
#  Text(0,0,'Clayton Kershaw'),
#  Text(0,0,'Dakota Hudson'),
#  Text(0,0,'Eduardo Rodriguez'),
#  Text(0,0,'German Marquez'),
#  Text(0,0,'Gerrit Cole'),
#  Text(0,0,'Hyun-Jin Ryu'),
#  Text(0,0,'Ivan Nova'),
#  Text(0,0,'Jack Flaherty'),
#  Text(0,0,'Jacob deGrom'),
#  Text(0,0,'Jakob Junis'),
#  Text(0,0,'Jeff Samardzija'),
#  Text(0,0,'Joe Musgrove'),
#  Text(0,0,'Joey Lucchesi'),
#  Text(0,0,'Jon Lester'),
#  Text(0,0,'Jose Berrios'),
#  Text(0,0,'Jose Quintana'),
#  Text(0,0,'Julio Teheran'),
#  Text(0,0,'Justin Verlander'),
#  Text(0,0,'Kyle Hendricks'),
#  Text(0,0,'Lance Lynn'),
#  Text(0,0,'Lucas Giolito'),
#  Text(0,0,'Madison Bumgarner'),
#  Text(0,0,'Marco Gonzales'),
#  Text(0,0,'Marcus Stroman'),
#  Text(0,0,'Martin Perez'),
#  Text(0,0,'Masahiro Tanaka'),
# ...

# %%
#WAR distribution for position players
chart= sns.barplot(x='Name',y='WAR',data=mlb_player_batting.sort_values(["WAR"],ascending=False))
sns.set(rc={'figure.figsize':(80,5)})
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Mike Trout'),
#  Text(0,0,'Alex Bregman'),
#  Text(0,0,'Cody Bellinger'),
#  Text(0,0,'Christian Yelich'),
#  Text(0,0,'Marcus Semien'),
#  Text(0,0,'Ketel Marte'),
#  Text(0,0,'Anthony Rendon'),
#  Text(0,0,'Xander Bogaerts'),
#  Text(0,0,'Mookie Betts'),
#  Text(0,0,'George Springer'),
#  Text(0,0,'Matt Chapman'),
#  Text(0,0,'Rafael Devers'),
#  Text(0,0,'Nolan Arenado'),
#  Text(0,0,'Trevor Story'),
#  Text(0,0,'J.T. Realmuto'),
#  Text(0,0,'Yoan Moncada'),
#  Text(0,0,'Ronald Acuna Jr.'),
#  Text(0,0,'DJ LeMahieu'),
#  Text(0,0,'Yasmani Grandal'),
#  Text(0,0,'Josh Donaldson'),
#  Text(0,0,'Juan Soto'),
#  Text(0,0,'Kris Bryant'),
#  Text(0,0,'Pete Alonso'),
#  Text(0,0,'Max Muncy'),
#  Text(0,0,'Ozzie Albies'),
#  Text(0,0,'Bryce Harper'),
#  Text(0,0,'Jeff McNeil'),
#  Text(0,0,'Eugenio Suarez'),
#  Text(0,0,'Francisco Lindor'),
#  Text(0,0,'Max Kepler'),
#  Text(0,0,'Javier Baez'),
#  Text(0,0,'Carlos Santana'),
#  Text(0,0,'Nelson Cruz'),
# ...

# %%
#WAR distribution for position players
chart= sns.barplot(x='Name',y='WAR',data=mlb_player_pitching.sort_values(["WAR"],ascending=False))
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Gerrit Cole'),
#  Text(0,0,'Jacob deGrom'),
#  Text(0,0,'Lance Lynn'),
#  Text(0,0,'Max Scherzer'),
#  Text(0,0,'Justin Verlander'),
#  Text(0,0,'Charlie Morton'),
#  Text(0,0,'Stephen Strasburg'),
#  Text(0,0,'Shane Bieber'),
#  Text(0,0,'Zack Greinke'),
#  Text(0,0,'Lucas Giolito'),
#  Text(0,0,'Walker Buehler'),
#  Text(0,0,'Hyun-Jin Ryu'),
#  Text(0,0,'Patrick Corbin'),
#  Text(0,0,'Jack Flaherty'),
#  Text(0,0,'Zack Wheeler'),
#  Text(0,0,'Noah Syndergaard'),
#  Text(0,0,'Sonny Gray'),
#  Text(0,0,'Jose Berrios'),
#  Text(0,0,'Mike Minor'),
#  Text(0,0,'Kyle Hendricks'),
#  Text(0,0,'Marcus Stroman'),
#  Text(0,0,'Marco Gonzales'),
#  Text(0,0,'Eduardo Rodriguez'),
#  Text(0,0,'Jose Quintana'),
#  Text(0,0,'Aaron Nola'),
#  Text(0,0,'German Marquez'),
#  Text(0,0,'Clayton Kershaw'),
#  Text(0,0,'Masahiro Tanaka'),
#  Text(0,0,'Trevor Bauer'),
#  Text(0,0,'Joe Musgrove'),
#  Text(0,0,'Matthew Boyd'),
#  Text(0,0,'Madison Bumgarner'),
#  Text(0,0,'Max Fried'),
# ...

# %%
#Team WAR comparison
chart= sns.barplot(x='Team',y='WAR',data=League_WAR.sort_values(["WAR"],ascending=False))
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Astros'),
#  Text(0,0,'Dodgers'),
#  Text(0,0,'Yankees'),
#  Text(0,0,'Twins'),
#  Text(0,0,'Athletics'),
#  Text(0,0,'Red Sox'),
#  Text(0,0,'Braves'),
#  Text(0,0,'Nationals'),
#  Text(0,0,'Cubs'),
#  Text(0,0,'Brewers'),
#  Text(0,0,'Mets'),
#  Text(0,0,'Diamondbacks'),
#  Text(0,0,'Rays'),
#  Text(0,0,'Cardinals'),
#  Text(0,0,'Phillies'),
#  Text(0,0,'Angels'),
#  Text(0,0,'Indians'),
#  Text(0,0,'Mariners'),
#  Text(0,0,'Padres'),
#  Text(0,0,'Blue Jays'),
#  Text(0,0,'Reds'),
#  Text(0,0,'White Sox'),
#  Text(0,0,'Pirates'),
#  Text(0,0,'Rockies'),
#  Text(0,0,'Giants'),
#  Text(0,0,'Royals'),
#  Text(0,0,'Rangers'),
#  Text(0,0,'Orioles'),
#  Text(0,0,'Marlins'),
#  Text(0,0,'Tigers')]

# %%
#Team pitching WAR comparison
chart= sns.barplot(x='Team',y='WAR',data=League_Pitching_WAR.sort_values(["WAR"],ascending=False))
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Rays'),
#  Text(0,0,'Dodgers'),
#  Text(0,0,'Twins'),
#  Text(0,0,'Astros'),
#  Text(0,0,'Nationals'),
#  Text(0,0,'Indians'),
#  Text(0,0,'Mets'),
#  Text(0,0,'Athletics'),
#  Text(0,0,'Reds'),
#  Text(0,0,'Yankees'),
#  Text(0,0,'Cubs'),
#  Text(0,0,'Red Sox'),
#  Text(0,0,'Padres'),
#  Text(0,0,'Cardinals'),
#  Text(0,0,'Rangers'),
#  Text(0,0,'Diamondbacks'),
#  Text(0,0,'Brewers'),
#  Text(0,0,'Braves'),
#  Text(0,0,'White Sox'),
#  Text(0,0,'Tigers'),
#  Text(0,0,'Blue Jays'),
#  Text(0,0,'Pirates'),
#  Text(0,0,'Phillies'),
#  Text(0,0,'Royals'),
#  Text(0,0,'Giants'),
#  Text(0,0,'Rockies'),
#  Text(0,0,'Marlins'),
#  Text(0,0,'Angels'),
#  Text(0,0,'Mariners'),
#  Text(0,0,'Orioles')]

# %%
war=pd.read_csv('C:/Users/jcase/Downloads/mlb2019war.csv')

# %%
#WAR compared to Win%
sns.regplot(x="Win %", y="WAR", data=war)
plt.title("2019 War v Win % ")
plt.show()

# %%
#Lin Reg of plot
x = war['Win %']
y = war['WAR']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("Slope and R^2 Value")
print ("Slope:", slope)
print("R^2 Value:", r_value**2)
# Out:
# Slope and R^2 Value
# Slope: 95.90853469811336
# R^2 Value: 0.8546300337775173

# %%
#Team worth - payroll
war1={"Team":war['Team'],"Difference":war["Worth"]-war["Payroll"]}
war2=pd.DataFrame(war1)
war2
# Out:
#             Team  Difference
# 0         Angels      929615
# 1         Astros   157695075
# 2      Athletics   134605469
# 3      Blue Jays   -19471067
# 4         Braves    71152037
# 5        Brewers    57510981
# 6      Cardinals     4282836
# 7           Cubs   -22690085
# 8   Diamondbacks    68372095
# 9        Dodgers    71299186
# 10        Giants   -98582126
# 11       Indians    50006253
# 12      Mariners   -12991293
# 13       Marlins   -54596271
# 14          Mets    40864188
# 15     Nationals    35792192
# 16       Orioles   -22416689
# 17        Padres     2745210
# 18      Phillies     7062756
# 19       Pirates    14068526
# 20       Rangers   -74638766
# 21          Rays   120021278
# 22       Red Sox    -9196106
# 23          Reds   -39691569
# 24       Rockies   -76262629
# 25        Royals   -29973003
# 26        Tigers  -135231137
# 27         Twins   123043997
# 28     White Sox    -3171201
# 29       Yankees    38980963

# %%
#Plot the difference
chart= sns.barplot(x='Team',y='Difference',data=war2)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Angels'),
#  Text(0,0,'Astros'),
#  Text(0,0,'Athletics'),
#  Text(0,0,'Blue Jays'),
#  Text(0,0,'Braves'),
#  Text(0,0,'Brewers'),
#  Text(0,0,'Cardinals'),
#  Text(0,0,'Cubs'),
#  Text(0,0,'Diamondbacks'),
#  Text(0,0,'Dodgers'),
#  Text(0,0,'Giants'),
#  Text(0,0,'Indians'),
#  Text(0,0,'Mariners'),
#  Text(0,0,'Marlins'),
#  Text(0,0,'Mets'),
#  Text(0,0,'Nationals'),
#  Text(0,0,'Orioles'),
#  Text(0,0,'Padres'),
#  Text(0,0,'Phillies'),
#  Text(0,0,'Pirates'),
#  Text(0,0,'Rangers'),
#  Text(0,0,'Rays'),
#  Text(0,0,'Red Sox'),
#  Text(0,0,'Reds'),
#  Text(0,0,'Rockies'),
#  Text(0,0,'Royals'),
#  Text(0,0,'Tigers'),
#  Text(0,0,'Twins'),
#  Text(0,0,'White Sox'),
#  Text(0,0,'Yankees')]

# %%
#League salary
chart= sns.barplot(x='NAME',y='SALARY',data=mlb_salary_2019.sort_values(["SALARY"],ascending=False))
sns.set(rc={'figure.figsize':(150,5)})

chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Max Scherzer'),
#  Text(0,0,'Stephen Strasburg'),
#  Text(0,0,'Mike Trout'),
#  Text(0,0,'Zack Greinke'),
#  Text(0,0,'David Price'),
#  Text(0,0,'Clayton Kershaw'),
#  Text(0,0,'Miguel Cabrera'),
#  Text(0,0,'Yoenis Cespedes'),
#  Text(0,0,'Justin Verlander'),
#  Text(0,0,'Albert Pujols'),
#  Text(0,0,'Felix Hernandez'),
#  Text(0,0,'Jon Lester'),
#  Text(0,0,'Nolan Arenado'),
#  Text(0,0,'Giancarlo Stanton'),
#  Text(0,0,'Joey Votto'),
#  Text(0,0,'Jordan Zimmermann'),
#  Text(0,0,'Jake Arrieta'),
#  Text(0,0,'Robinson Cano'),
#  Text(0,0,'J.D. Martinez'),
#  Text(0,0,'Edwin Encarnacion'),
#  Text(0,0,'Josh Donaldson'),
#  Text(0,0,'Johnny Cueto'),
#  Text(0,0,'Buster Posey'),
#  Text(0,0,'Masahiro Tanaka'),
#  Text(0,0,'Jacoby Ellsbury'),
#  Text(0,0,'Eric Hosmer'),
#  Text(0,0,'Charlie Blackmon'),
#  Text(0,0,'Matt Kemp'),
#  Text(0,0,'Freddie Freeman'),
#  Text(0,0,'Rick Porcello'),
#  Text(0,0,'Chris Davis'),
#  Text(0,0,'Alex Gordon'),
#  Text(0,0,'Shin-Soo Choo'),
# ...

# %%
mlb_salary_2019.sort_values(["SALARY"],ascending=False)
# Out:
#      Year  RANK               NAME                   TEAM POS    SALARY  \
# 0    2019     1       Max Scherzer   Washington Nationals  SP  42142857
# 1    2019     2  Stephen Strasburg   Washington Nationals  SP  36428571
# 2    2019     3         Mike Trout      Los Angeles Angel  CF  34083333
# 3    2019     4       Zack Greinke   Arizona Diamondbacks  SP  32421884
# 4    2019     5        David Price         Boston Red Sox  SP  31000000
# 5    2019     5    Clayton Kershaw    Los Angeles Dodgers  SP  31000000
# 6    2019     7     Miguel Cabrera         Detroit Tigers  DH  30000000
# 7    2019     8    Yoenis Cespedes          New York Mets  OF  29000000
# 8    2019     9   Justin Verlander         Houston Astros  SP  28000000
# 9    2019     9      Albert Pujols      Los Angeles Angel  DH  28000000
# 10   2019    11    Felix Hernandez       Seattle Mariners  SP  27857143
# 11   2019    12         Jon Lester           Chicago Cubs  SP  27500000
# ...

# %%
#average salary
mlb_salary_2019["SALARY"].mean()
# Out:
# 4509877.567844925

# %%
#average war for pitchers
mlb_player_pitching["WAR"].mean()
# Out:
# 3.5017543859649134

# %%
#average war for position players
mlb_player_batting["WAR"].mean()
# Out:
# 3.0167938931297713

# %%
#Cubs 2019 salary
dfp1={"Name":Cubs_Pitching['Name'],"Salary":Cubs_Pitching["Salary"]}
CP_Dif1=pd.DataFrame(dfp1)
CP_Dif1.sort_values(["Salary"],ascending=False)
# Out:
#                 Name    Salary
# 2         Jon Lester  27500000
# 3         Yu Darvish  20000000
# 4        Cole Hamels  20000000
# 6     Tyler Chatwood  12500000
# 1      Jose Quintana  10500000
# 16     Craig Kimbrel  10000000
# 8       Steve Cishek   7500000
# 0     Kyle Hendricks   7405000
# 9        Pedro Strop   6250000
# 5   Brandon Kintzler   5000000
# 7         Brad Brach   3000000
# 15   Mike Montgomery   2440000
# 11  Carl Edwards Jr.   1500000
# 10     Xavier Cedeno    900000
# 14     Tony Barnette    750000
# 13   Victor Caratini    569500
# 12     Randy Rosario    564000

# %%
##Cubs 2019 salary
dfb1={"Name":Cubs_Batting['Name'],"Salary":Cubs_Batting["Salary"]}
Cb_Dif1=pd.DataFrame(dfb1)
Cb_Dif1.sort_values(["Salary"],ascending=False)
# Out:
#                  Name    Salary
# 5       Jason Heyward  20000000
# 0         Kris Bryant  12900000
# 10        Ben Zobrist  12500000
# 2       Anthony Rizzo  12285714
# 1         Javier Baez   5200000
# 9     Addison Russell   3400000
# 4      Kyle Schwarber   3390000
# 13    Daniel Descalso   2000000
# 3   Willson Contreras    684000
# 12  Albert Almora Jr.    615500
# 7            Ian Happ    603500
# 8     Victor Caratini    569500
# 6          David Bote    561500
# 11       Mark Zagunis    556500
